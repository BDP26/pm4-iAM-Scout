# %% [markdown]
# # Scraping Environment Test
# Testet alle wichtigen Scraping-Libraries

# %%
# Test Imports
import requests
import pandas as pd
from bs4 import BeautifulSoup
from playwright.sync_api import sync_playwright
from selenium import webdriver
import time
import os

print('✅ Alle Libraries erfolgreich importiert!')

# %%
# Test einfaches Web Scraping mit requests
response = requests.get('https://httpbin.org/json')
print(f'Status Code: {response.status_code}')
print(f'Response: {response.json()}')

# %%
# Test Playwright
with sync_playwright() as p:
    browser = p.chromium.launch(headless=True)
    page = browser.new_page()
    page.goto('https://httpbin.org')
    title = page.title()
    print(f'✅ Playwright funktioniert! Page Title: {title}')
    browser.close()
